# %% [markdown]
# # **Práctica 04: Análisis Exploratorio de Datos con Python y Jupyter Notebook**
#
# ---
#
# ## **Programa de Estudios**
#
# Ingeniería en Desarrollo y Gestión de Software
#
# ## **Asignatura**
#
# Extracción de Conocimiento en Bases de Datos
#
# ## **Docente**
#
# M.T.I. Marco A. Ramírez Hernández
#
# ## **Periodo**
#
# Mayo – Agosto 2026
#
# ## **Unidad 2**
#
# Preparación de los Datos
#
# ---
#
# ## **Nombre del Estudiante**: Brian Jesus Mendoza Marquez
#
# ## **Matrícula** : 230308
#
# ## **Grado y Grupo** : 9A
#
# # **Introducción**
#
# El análisis exploratorio de datos (*Exploratory Data Analysis - EDA*) es una etapa fundamental dentro del proceso de extracción de conocimiento en bases de datos. Su principal objetivo consiste en comprender, analizar y visualizar la información contenida en un conjunto de datos (*dataset*) antes de aplicar modelos avanzados de análisis o inteligencia artificial.
#
# En esta práctica, el estudiante aprenderá a realizar un análisis exploratorio de datos utilizando el lenguaje de programación Python y el entorno interactivo Jupyter Notebook. Además, se utilizarán diversas librerías especializadas para la carga, manipulación, análisis y visualización de datos.
#
# ---
#
# # **Objetivo de la Práctica**
#
# El estudiante practicará cómo realizar un análisis exploratorio de datos (EDA), utilizando el lenguaje de programación Python y librerías comunes para la carga, manipulación, análisis y visualización previa de un conjunto de datos (*dataset*).
#
# ---
#
# # **Librerías Utilizadas**
#
# Para esta práctica se utilizarán las siguientes librerías:
#
# * Pandas
# * NumPy
# * Seaborn
# * OS
# * Matplotlib
#
# ---
#
# # **1. Importar Librerías Necesarias para Realizar el EDA**
#
# Comenzaremos importando las librerías necesarias que permitirán manipular, analizar y visualizar los datos extraídos desde una fuente de datos (*Data Source*).

# %% [markdown]
# El estudiante practicara como realizar un analisis exploratorio de datos , utilizando el lenguaje de programacion de Python, y librerias comunes para la carga , manipulacion , analisis y visualizacion previa de un conjunto de datos (Datatest), para esta practica se utilizaran librerias de:
#
# - Pandas
# - Numpy
# - Seabron
# - os
# - Matplotlib

# %% [markdown]
# 1. Importar las librerias necesarias para realizar el EDA
#
#  Comenzamos por importar la libreria que nos permitira manipular los datos del datatest extraordinarios de una fuente de datos (datasource)

# %%
import pandas as pd

# %% [markdown]
# # **2. Creamos un DataFrame , leyendo el archivo delimiatdo por comas (.CSV)**

# %%
pokemons = pd.read_csv('./Pokemons.csv')

# %% [markdown]
# # **3-. Imprimir el resultado de la lectura inicial de los datos cargados**

# %% [markdown]
# 3. Este comando imprime en una tabla las columnas y las filas del dataframe , siemprede manera estandar nos
# mostrara los primeros 5 y los ultimos 5 registros del dataframe

# %%
pokemons
# Out:
#        #                   Name      Type 1  Type 2  Total   HP  Attack  \
# 0    1.0              Bulbasaur       Grass  Poison  318.0   45      49
# 1    2.0                Ivysaur       Grass  Poison  405.0   60      62
# 2    3.0               Venusaur       Grass  Poison  525.0   80      82
# 3    3.0  VenusaurMega Venusaur       Grass  Poison  625.0   80     100
# 4    4.0             Charmander        Fire     NaN  309.0   39      52
# ..   ...                    ...         ...     ...    ...  ...     ...
# 805  NaN               Cybermon  Artificial     NaN    NaN   90      95
# 806  NaN              Mechazard  Artificial     NaN    NaN   85     120
# 807  NaN                Datagon  Artificial     NaN    NaN  100     110
# 808  NaN              Roboflare  Artificial     NaN    NaN   75     130
# 809  NaN               Neuralix  Artificial     NaN    NaN   95     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Armor
# ...

# %% [markdown]
# # **4. Obtener una muestra aleatoria de registros del DataFrame usando el metodo **.sample****

# %% [markdown]
# Como parametro de entrada podemos definir en un entero que determina el tamaño de la muestra

# %%
pokemons.sample(7) ## Obtiene una muestra de 7 pokemons aleatoria
# Out:
#          #                  Name   Type 1   Type 2  Total  HP  Attack  \
# 523  472.0               Gliscor   Ground   Flying  510.0  75      95
# 192  178.0                  Xatu  Psychic   Flying  470.0  65      75
# 637  576.0            Gothitelle  Psychic      NaN  490.0  70      55
# 418  380.0     LatiasMega Latias   Dragon  Psychic  700.0  80     100
# 578  519.0                Pidove   Normal   Flying  264.0  50      55
# 440  395.0              Empoleon    Water    Steel  530.0  84      86
# 750  681.0  AegislashBlade Forme    Steel    Ghost  520.0  60     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Armor
# 523      125       45       75     95         4.0     False    150
# 192       70       95       70     95         2.0     False     84
# 637       95       95      110     65         5.0     False    114
# 418      120      140      150    110         3.0      True    144
# 578       50       36       30     43         5.0     False     60
# ...

# %% [markdown]
# **Ejercicio 1:** Obten una muestra de 50 pokemons

# %%
pokemons.sample(50) ## Resultados
# Out:
#          #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 445  400.0                  Bibarel    Normal     Water  410.0   79      85
# 739  671.0                  Florges     Fairy       NaN  552.0   78      65
# 686  625.0                  Bisharp      Dark     Steel  490.0   65     125
# 296  273.0                   Seedot     Grass       NaN  220.0   40      40
# 397  362.0        GlalieMega Glalie       Ice       NaN  580.0   80     120
# 287  264.0                  Linoone    Normal       NaN  420.0   78      70
# 636  575.0                Gothorita   Psychic       NaN  390.0   60      45
# 244  226.0                  Mantine     Water    Flying  465.0   65      40
# 306  282.0  GardevoirMega Gardevoir   Psychic     Fairy  618.0   68      85
# 738  670.0                  Floette     Fairy       NaN  371.0   54      45
# 155  143.0                  Snorlax    Normal       NaN  540.0  160     110
# ...

# %% [markdown]
# # **5. Obtener una muestra de rangos definidos usando **.iloc****

# %%
pokemons_100_to_200 = pokemons.iloc[100:200]
pokemons_100_to_200
# Out:
#          #                   Name    Type 1  Type 2  Total   HP  Attack  \
# 100   93.0                Haunter     Ghost  Poison  405.0   45      50
# 101   94.0                 Gengar     Ghost  Poison  500.0   60      65
# 102   94.0      GengarMega Gengar     Ghost  Poison  600.0   60      65
# 103   95.0                   Onix      Rock  Ground  385.0   35      45
# 104   96.0                Drowzee   Psychic     NaN  328.0   60      48
# ..     ...                    ...       ...     ...    ...  ...     ...
# 195  181.0               Ampharos  Electric     NaN  510.0   90      75
# 196  181.0  AmpharosMega Ampharos  Electric  Dragon  610.0   90      95
# 197  182.0              Bellossom     Grass     NaN  490.0   75      80
# 198  183.0                 Marill     Water   Fairy  250.0   70      20
# 199  184.0              Azumarill     Water   Fairy  420.0  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Armor
# ...

# %% [markdown]
#  # **6. Como saber las columnas o atributos tiene el dataframe**

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Armor'],
#       dtype='object')

# %% [markdown]
# | Campo | Descripción |
# |---------|-------------|
# | **#** | Identificador único o número asignado a cada Pokémon dentro de la Pokédex. |
# | **Name** | Nombre oficial del Pokémon. |
# | **Type 1** | Tipo principal del Pokémon. Los tipos representan afinidades elementales como Agua, Fuego, Planta, Eléctrico, entre otros, e influyen en las fortalezas y debilidades durante los combates. |
# | **Type 2** | Tipo secundario del Pokémon. No todos los Pokémon poseen un segundo tipo; cuando existe, complementa sus características y habilidades en batalla. |
# | **Total** | Suma total de todas las estadísticas base del Pokémon. Proporciona una medida general de su potencial y nivel de poder. |
# | **HP** | *Health Points* (Puntos de Salud). Determina la cantidad de daño que un Pokémon puede recibir antes de quedar fuera de combate. |
# | **Attack** | Estadística que representa la potencia de los ataques físicos realizados por el Pokémon. |
# | **Defense** | Mide la capacidad del Pokémon para resistir ataques físicos de otros Pokémon. |
# | **Sp. Atk** | *Special Attack* (Ataque Especial). Determina la fuerza de los movimientos especiales del Pokémon. |
# | **Sp. Def** | *Special Defense* (Defensa Especial). Indica la resistencia del Pokémon frente a ataques especiales. |
# | **Speed** | Velocidad del Pokémon. Generalmente, el Pokémon con mayor velocidad tiene prioridad para atacar durante un combate. |
# | **Generation** | Generación de videojuegos a la que pertenece el Pokémon. Cada generación introduce nuevas especies, mecánicas y regiones dentro de la franquicia. |
# | **Legendary** | Variable booleana que indica si el Pokémon es legendario (**True**) o no (**False**). Los Pokémon legendarios suelen ser más raros y poseen estadísticas superiores al promedio. |

# %% [markdown]
#  # **7.  Explorar la composicion y ausencia de datos  (METADATA) con **.info****

# %% [markdown]
# La libreria de pandas , incluye un metodo que nos permite evaluar el tipo de datos y su composicion y ausencia

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    float64
#  1   Name        810 non-null    object
#  2   Type 1      810 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    float64
#  5   HP          810 non-null    int64
#  6   Attack      810 non-null    int64
#  7   Defense     810 non-null    int64
#  8   Sp. Atk     810 non-null    int64
#  9   Sp. Def     810 non-null    int64
#  10  Speed       810 non-null    int64
#  11  Generation  800 non-null    float64
#  12  Legendary   800 non-null    object
#  13  Armor       810 non-null    int64
# dtypes: float64(3), int64(7), object(4)
# memory usage: 88.7+ KB

# %% [markdown]
# # **8. Limpieza de Datos, eliminar columna inecesarias para el analisis**
#
# Dependiendo del objetivo de analisis algunas columnas no seran necesarias en nuestro dataframe , en estte caso omitiremos los datos vacios ,
# por los que eliminaremos la columna 'Type 2', y renombraremos la columba por 'Type 1' por 'Type'

# %%
# Check if 'Type 2' column exists before dropping it, and handle the case where it doesn't exist
if 'Type 2' in pokemons.columns:
    pokemons = pokemons.drop(columns=['Type 2']).rename(columns={'Type 1': 'Type'})
else:
    # If 'Type 2' doesn't exist, just rename 'Type 1' to 'Type'
    pokemons = pokemons.rename(columns={'Type 1': 'Type'})

# Alternative solution: Use errors='ignore' parameter to silently skip missing columns
# pokemons = pokemons.drop(columns=['Type 2'], errors='ignore').rename(columns={'Type 1': 'Type'})

# %%
pokemons
# Out:
#        #                   Name        Type  Total   HP  Attack  Defense  \
# 0    1.0              Bulbasaur       Grass  318.0   45      49       49
# 1    2.0                Ivysaur       Grass  405.0   60      62       63
# 2    3.0               Venusaur       Grass  525.0   80      82       83
# 3    3.0  VenusaurMega Venusaur       Grass  625.0   80     100      123
# 4    4.0             Charmander        Fire  309.0   39      52       43
# ..   ...                    ...         ...    ...  ...     ...      ...
# 805  NaN               Cybermon  Artificial    NaN   90      95      110
# 806  NaN              Mechazard  Artificial    NaN   85     120      100
# 807  NaN                Datagon  Artificial    NaN  100     110      120
# 808  NaN              Roboflare  Artificial    NaN   75     130       80
# 809  NaN               Neuralix  Artificial    NaN   95     100      105
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  Armor
# ...

# %% [markdown]
# **Ejercicio 02:** Consulta la METADATA de la actualizacion y compara los cambios con la anterior
#
# ¿Qué cambios vez? redacta tu respuesta

# %% [markdown]
# # **9. Visualizacion de los primeros datos usando el metodo **.head****

# %%
pokemons.head()
# Out:
#      #                   Name   Type  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1.0              Bulbasaur  Grass  318.0  45      49       49       65
# 1  2.0                Ivysaur  Grass  405.0  60      62       63       80
# 2  3.0               Venusaur  Grass  525.0  80      82       83      100
# 3  3.0  VenusaurMega Venusaur  Grass  625.0  80     100      123      122
# 4  4.0             Charmander   Fire  309.0  39      52       43       60
#
#    Sp. Def  Speed  Generation Legendary  Armor
# 0       65     45         1.0     False     58
# 1       80     60         1.0     False     75
# 2      100     80         1.0     False     99
# 3      120     80         1.0     False    147
# 4       50     65         1.0     False     51

# %% [markdown]
# **Ejercicio 03:** Muestra los ultimos 10 registros del dataframe

# %%
pokemons.tail(10)
# Out:
#       #       Name        Type  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 800 NaN   Cybermon  Artificial    NaN   90      95      110      100       95
# 801 NaN  Mechazard  Artificial    NaN   85     120      100       90       80
# 802 NaN    Datagon  Artificial    NaN  100     110      120      105      110
# 803 NaN  Roboflare  Artificial    NaN   75     130       80      120       85
# 804 NaN   Neuralix  Artificial    NaN   95     100      105      130      125
# 805 NaN   Cybermon  Artificial    NaN   90      95      110      100       95
# 806 NaN  Mechazard  Artificial    NaN   85     120      100       90       80
# 807 NaN    Datagon  Artificial    NaN  100     110      120      105      110
# 808 NaN  Roboflare  Artificial    NaN   75     130       80      120       85
# 809 NaN   Neuralix  Artificial    NaN   95     100      105      130      125
#
#      Speed  Generation Legendary  Armor
# 800     85         NaN       NaN    132
# ...

# %% [markdown]
# # **10. Estadisticas basicas del Dataframe**
#
# Pandas permite emitir un reporte de estadtidistica basica (medidas de tendencia) sobre datos cuantitativos usando el comando **.describe**

# %%
pokemons.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  810.000000  810.000000  810.000000  810.000000
# mean   362.813750  435.10250   69.502469   79.396296   74.202469   73.266667
# std    208.343798  119.96304   25.487884   32.480550   31.192072   32.802673
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   50.000000
# 50%    364.500000  450.00000   65.500000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation      Armor
# count  810.000000  810.000000   800.00000  810.00000
# mean    72.237037   68.533333     3.32375   88.92716
# std     27.878788   29.020806     1.66129   37.44799
# min     20.000000    5.000000     1.00000    6.00000
# ...

# %% [markdown]
# # **11. Calcular el total de datos no duplicados (unicos)**
#
# Usaremos **.len()** como funcion para calcular la longitud del dataframe y **.unique()** para excluir duplicados
#
# **NOTA:** No considerar ID como un atributo de llave primaria , sino el total de columnas como un solo elemento u objeto.

# %% [markdown]
# Obteniendo los valores unicos por columna en este caso la columna "Name"

# %%
len(pokemons.Name.unique())
# Out:
# 805

# %%
total_unicos = len(pokemons.drop_duplicates())
total_unicos
# Out:
# 805

# %% [markdown]
# **Ejercicio 04:** Obtener el total de IDs unicos en el datatest

# %%
total_ids_unicos = pokemons['#'].nunique()
total_ids_unicos
# Out:
# 721

# %% [markdown]
# **Ejercicio 05:** Obtener el total de Tipos de Pokemons

# %%
total_ids_unicos = pokemons['Type'].nunique()
total_ids_unicos
# Out:
# 19

# %% [markdown]
# ### Librerias

# %% [markdown]
# ### 1. NumPy
#  Sirve para hacer cálculos matemáticos con millones de números a toda velocidad.

# %%
import numpy as np

# %% [markdown]
# ### 2. Pandas
# Sirve para abrir, limpiar y ordenar tablas de datos (como si fuera un Excel).

# %%
import pandas as pd

# %% [markdown]
# ### 3. Matplotlib

# %% [markdown]
# Sirve para dibujar gráficos básicos desde cero (líneas, barras, puntos).

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 4.Seaborn
# Sirve para hacer esos mismos gráficos, pero más bonitos y profesionales de forma automática.

# %%
import seaborn as sns

# %% [markdown]
# ### 4.OS
# Sirve para que tu código pueda buscar y abrir carpetas dentro de tu computadora.

# %%
import os

# %% [markdown]
# ### 5.Bucle for
# Sirve para listar y mostrar en pantalla los archivos que tienes disponibles para trabajar.

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ### Importing the data

# %% [markdown]
# Este código utiliza la librería Pandas para abrir el archivo llamado Pokemon.csv ubicado en la ruta especificada y carga toda su información dentro de una variable llamada pokemons. Al hacer esto, transforma ese archivo de texto con datos separados por comas en una tabla digital interactiva dentro de Python, permitiéndote empezar a explorar, filtrar o graficar las estadísticas de los Pokémon de forma inmediata.

# %%
pokemons=pd.read_csv('Pokemons.csv')

# %% [markdown]
# ### Análisis Exploratorio de Datos (EDA) sobre Pokémon
# ¿Cuántos Pokémon hay en cada generación?

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# 1.0    166
# 5.0    165
# 3.0    160
# 4.0    121
# 2.0    106
# 6.0     82
# Name: count, dtype: int64

# %% [markdown]
# ### Distribución de Pokémon por generación.
# Este bloque de código silencia las advertencias del sistema para mantener la pantalla limpia, cuenta de forma automática cuántos Pokémon pertenecen a cada generación en un gráfico de barras utilizando la gama cromática nipy_spectral, y le añade el título en la parte superior.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

sns.countplot(x='Generation', data=pokemons, palette='nipy_spectral')
plt.title('Number of pokemons grouped by generation')
# Out:
# Text(0.5, 1.0, 'Number of pokemons grouped by generation')

# %%
pokemons['Type 1'].value_counts()
# Out:
# Type 1
# Water         112
# Normal         98
# Grass          70
# Bug            69
# Psychic        57
# Fire           52
# Electric       44
# Rock           44
# Dragon         32
# Ground         32
# Ghost          32
# Dark           31
# Poison         28
# Steel          27
# Fighting       27
# Ice            24
# Fairy          17
# Artificial     10
# Flying          4
# Name: count, dtype: int64
